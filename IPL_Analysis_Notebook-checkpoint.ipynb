# %% [markdown]
# # IPL Match Analysis Project\nThis notebook analyzes IPL match data using Pandas and Matplotlib.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('matches(3).csv')\ndf.head()

# %%
df.shape\ndf.info()

# %%
df['season'].value_counts().sort_index().plot(kind='bar', figsize=(10,5), title='Matches per Season')\nplt.xlabel('Season')\nplt.ylabel('Matches')\nplt.tight_layout()\nplt.show()

# %%
df['winner'].value_counts().head(10).plot(kind='bar', figsize=(10,5), title='Top 10 Winning Teams')\nplt.xlabel('Team')\nplt.ylabel('Wins')\nplt.tight_layout()\nplt.show()

# %%
toss_win_pct = (df['toss_winner'] == df['winner']).mean() * 100\nprint('Toss winner also match winner %:', round(toss_win_pct, 2))

# %%
df['player_of_match'].value_counts().head(10).plot(kind='bar', figsize=(10,5), title='Top Player of Match Winners')\nplt.xlabel('Player')\nplt.ylabel('Awards')\nplt.tight_layout()\nplt.show()
